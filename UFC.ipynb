# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('ufc_fighter_details.csv')

# %%
df
# Out:
#         FIRST        LAST      NICKNAME  \
# 0         Tom       Aaron           NaN
# 1       Danny      Abbadi  The Assassin
# 2     Nariman     Abbasov     Bayraktar
# 3       David      Abbott          Tank
# 4       Hamdy  Abdelwahab    The Hammer
# ...       ...         ...           ...
# 3905     Dave    Zitanick           NaN
# 3906     Alex      Zuniga           NaN
# 3907   George      Zuniga           NaN
# 3908    Allan      Zuniga         Tigre
# 3909   Virgil     Zwicker        RezDog
#
#                                                     URL
# 0     http://ufcstats.com/fighter-details/93fe7332d1...
# 1     http://ufcstats.com/fighter-details/15df64c02b...
# 2     http://ufcstats.com/fighter-details/59a9d6dac6...
# 3     http://ufcstats.com/fighter-details/b361180739...
# 4     http://ufcstats.com/fighter-details/3329d692ae...
# ...                                                 ...
# 3905  http://ufcstats.com/fighter-details/be124bdd60...
# ...

# %%
dff = pd.read_csv('ufc_fighter_tott.csv')

# %%
dff
# Out:
#                   FIGHTER  HEIGHT    WEIGHT REACH    STANCE           DOB  \
# 0               Tom Aaron      --  155 lbs.    --       NaN  Jul 13, 1978
# 1            Danny Abbadi  5' 11"  155 lbs.    --  Orthodox  Jul 03, 1983
# 2            David Abbott   6' 0"  265 lbs.    --    Switch            --
# 3     Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox  Sep 02, 1981
# 4            Hiroyuki Abe   5' 6"  145 lbs.    --  Orthodox            --
# ...                   ...     ...       ...   ...       ...           ...
# 3909      Lucas Alexander  5' 10"  145 lbs.    --       NaN  Jul 28, 1995
# 3910        Gian Siqueira      --  170 lbs.    --       NaN  Jun 23, 1994
# 3911     Samandar Murodov      --  170 lbs.    --       NaN  Aug 28, 1999
# 3912          Carlos Mota   5' 6"  125 lbs.    --       NaN  Apr 15, 1995
# 3913  Gabriella Fernandes   5' 6"  125 lbs.    --       NaN  Aug 13, 1993
#
#                                                     URL
# ...

# %%
dff = dff.merge(df,on='URL')

# %%
dff
# Out:
#                   FIGHTER  HEIGHT    WEIGHT REACH    STANCE           DOB  \
# 0               Tom Aaron      --  155 lbs.    --       NaN  Jul 13, 1978
# 1            Danny Abbadi  5' 11"  155 lbs.    --  Orthodox  Jul 03, 1983
# 2            David Abbott   6' 0"  265 lbs.    --    Switch            --
# 3     Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox  Sep 02, 1981
# 4            Hiroyuki Abe   5' 6"  145 lbs.    --  Orthodox            --
# ...                   ...     ...       ...   ...       ...           ...
# 3905      Lucas Alexander  5' 10"  145 lbs.    --       NaN  Jul 28, 1995
# 3906        Gian Siqueira      --  170 lbs.    --       NaN  Jun 23, 1994
# 3907     Samandar Murodov      --  170 lbs.    --       NaN  Aug 28, 1999
# 3908          Carlos Mota   5' 6"  125 lbs.    --       NaN  Apr 15, 1995
# 3909  Gabriella Fernandes   5' 6"  125 lbs.    --       NaN  Aug 13, 1993
#
#                                                     URL      FIRST  \
# ...

# %%
dff = dff.drop(['URL','FIRST','LAST'],axis=1)

# %%
dff
# Out:
#                   FIGHTER  HEIGHT    WEIGHT REACH    STANCE           DOB  \
# 0               Tom Aaron      --  155 lbs.    --       NaN  Jul 13, 1978
# 1            Danny Abbadi  5' 11"  155 lbs.    --  Orthodox  Jul 03, 1983
# 2            David Abbott   6' 0"  265 lbs.    --    Switch            --
# 3     Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox  Sep 02, 1981
# 4            Hiroyuki Abe   5' 6"  145 lbs.    --  Orthodox            --
# ...                   ...     ...       ...   ...       ...           ...
# 3905      Lucas Alexander  5' 10"  145 lbs.    --       NaN  Jul 28, 1995
# 3906        Gian Siqueira      --  170 lbs.    --       NaN  Jun 23, 1994
# 3907     Samandar Murodov      --  170 lbs.    --       NaN  Aug 28, 1999
# 3908          Carlos Mota   5' 6"  125 lbs.    --       NaN  Apr 15, 1995
# 3909  Gabriella Fernandes   5' 6"  125 lbs.    --       NaN  Aug 13, 1993
#
#           NICKNAME
# 0              NaN
# 1     The Assassin
# ...

# %%
a = dff[dff['FIGHTER']== 'Jon Jones']

# %%
a
# Out:
#         FIGHTER HEIGHT    WEIGHT REACH    STANCE           DOB NICKNAME
# 1596  Jon Jones  6' 4"  205 lbs.   84"  Orthodox  Jul 19, 1987    Bones

# %%
stats = pd.read_csv('ufc_fight_stats.csv')

# %%
stats
# Out:
#                                     EVENT                             BOUT  \
# 0      UFC Fight Night: Grasso vs. Araujo  Alexa Grasso vs. Viviane Araujo
# 1      UFC Fight Night: Grasso vs. Araujo  Alexa Grasso vs. Viviane Araujo
# 2      UFC Fight Night: Grasso vs. Araujo  Alexa Grasso vs. Viviane Araujo
# 3      UFC Fight Night: Grasso vs. Araujo  Alexa Grasso vs. Viviane Araujo
# 4      UFC Fight Night: Grasso vs. Araujo  Alexa Grasso vs. Viviane Araujo
# ...                                   ...                              ...
# 31803                   UFC 2: No Way Out  Johnny Rhodes vs. David Levicki
# 31804                   UFC 2: No Way Out     Patrick Smith vs. Ray Wizard
# 31805                   UFC 2: No Way Out     Patrick Smith vs. Ray Wizard
# 31806                   UFC 2: No Way Out  Scott Morris vs. Sean Daugherty
# 31807                   UFC 2: No Way Out  Scott Morris vs. Sean Daugherty
#
# ...

# %%
p_stats = stats[stats['FIGHTER'] == 'Israel Adesanya']

# %%
p_stats
# Out:
#                                          EVENT  \
# 658            UFC 276: Adesanya vs. Cannonier
# 659            UFC 276: Adesanya vs. Cannonier
# 660            UFC 276: Adesanya vs. Cannonier
# 661            UFC 276: Adesanya vs. Cannonier
# 662            UFC 276: Adesanya vs. Cannonier
# 1706         UFC 271: Adesanya vs. Whittaker 2
# 1707         UFC 271: Adesanya vs. Whittaker 2
# 1708         UFC 271: Adesanya vs. Whittaker 2
# 1709         UFC 271: Adesanya vs. Whittaker 2
# 1710         UFC 271: Adesanya vs. Whittaker 2
# 3318           UFC 263: Adesanya vs. Vettori 2
# 3319           UFC 263: Adesanya vs. Vettori 2
# 3320           UFC 263: Adesanya vs. Vettori 2
# 3321           UFC 263: Adesanya vs. Vettori 2
# 3322           UFC 263: Adesanya vs. Vettori 2
# 4021          UFC 259: Blachowicz vs. Adesanya
# 4022          UFC 259: Blachowicz vs. Adesanya
# 4023          UFC 259: Blachowicz vs. Adesanya
# 4024          UFC 259: Blachowicz vs. Adesanya
# ...

# %%
result = pd.read_csv('ufc_fight_results.csv')

# %%
result
# Out:
#                                     EVENT  \
# 0     UFC Fight Night: Grasso vs. Araujo
# 1     UFC Fight Night: Grasso vs. Araujo
# 2     UFC Fight Night: Grasso vs. Araujo
# 3     UFC Fight Night: Grasso vs. Araujo
# 4     UFC Fight Night: Grasso vs. Araujo
# ...                                   ...
# 6822                   UFC 2: No Way Out
# 6823                   UFC 2: No Way Out
# 6824                   UFC 2: No Way Out
# 6825                   UFC 2: No Way Out
# 6826                   UFC 2: No Way Out
#
#                                        BOUT OUTCOME             WEIGHTCLASS  \
# 0         Alexa Grasso  vs. Viviane Araujo      W/L  Women's Flyweight Bout
# 1       Cub Swanson  vs. Jonathan Martinez      L/W       Bantamweight Bout
# 2       Jordan Wright  vs. Dusko Todorovic      L/W       Middleweight Bout
# 3       Raphael Assuncao  vs. Victor Henry      W/L       Bantamweight Bout
# 4     Misha Cirkunov  vs. Alonzo Menifield      L/W  Light Heavyweight Bout
# ...

# %%
dff
# Out:
#                   FIGHTER  HEIGHT    WEIGHT REACH    STANCE           DOB  \
# 0               Tom Aaron      --  155 lbs.    --       NaN  Jul 13, 1978
# 1            Danny Abbadi  5' 11"  155 lbs.    --  Orthodox  Jul 03, 1983
# 2            David Abbott   6' 0"  265 lbs.    --    Switch            --
# 3     Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox  Sep 02, 1981
# 4            Hiroyuki Abe   5' 6"  145 lbs.    --  Orthodox            --
# ...                   ...     ...       ...   ...       ...           ...
# 3905      Lucas Alexander  5' 10"  145 lbs.    --       NaN  Jul 28, 1995
# 3906        Gian Siqueira      --  170 lbs.    --       NaN  Jun 23, 1994
# 3907     Samandar Murodov      --  170 lbs.    --       NaN  Aug 28, 1999
# 3908          Carlos Mota   5' 6"  125 lbs.    --       NaN  Apr 15, 1995
# 3909  Gabriella Fernandes   5' 6"  125 lbs.    --       NaN  Aug 13, 1993
#
#           NICKNAME
# 0              NaN
# 1     The Assassin
# ...

# %%
dff
# Out:
#                   FIGHTER  HEIGHT    WEIGHT REACH    STANCE           DOB  \
# 0               Tom Aaron      --  155 lbs.    --       NaN  Jul 13, 1978
# 1            Danny Abbadi  5' 11"  155 lbs.    --  Orthodox  Jul 03, 1983
# 2            David Abbott   6' 0"  265 lbs.    --    Switch            --
# 3     Shamil Abdurakhimov   6' 3"  235 lbs.   76"  Orthodox  Sep 02, 1981
# 4            Hiroyuki Abe   5' 6"  145 lbs.    --  Orthodox            --
# ...                   ...     ...       ...   ...       ...           ...
# 3905      Lucas Alexander  5' 10"  145 lbs.    --       NaN  Jul 28, 1995
# 3906        Gian Siqueira      --  170 lbs.    --       NaN  Jun 23, 1994
# 3907     Samandar Murodov      --  170 lbs.    --       NaN  Aug 28, 1999
# 3908          Carlos Mota   5' 6"  125 lbs.    --       NaN  Apr 15, 1995
# 3909  Gabriella Fernandes   5' 6"  125 lbs.    --       NaN  Aug 13, 1993
#
#           NICKNAME
# 0              NaN
# 1     The Assassin
# ...

# %%
dff['STANCE'].unique()
# Out:
# array([nan, 'Orthodox', 'Switch', 'Southpaw', 'Open Stance', 'Sideways'],
#       dtype=object)

# %%
stance = np.unique(dff['STANCE'].dropna().values).tolist()

# %%
stance
# Out:
# ['Open Stance', 'Orthodox', 'Sideways', 'Southpaw', 'Switch']

# %%
x1 = dff[dff['STANCE'] == 'Open Stance'].count()['STANCE']

# %%
x1
# Out:
# 7

# %%
x2 = dff[dff['STANCE'] == 'Orthodox'].count()['STANCE']

# %%
x2
# Out:
# 2271

# %%
x3 = dff[dff['STANCE'] == 'Sideways'].count()['STANCE']

# %%
x3
# Out:
# 3

# %%
x4 = dff[dff['STANCE'] == 'Southpaw'].count()['STANCE']

# %%
x4
# Out:
# 509

# %%
x5 = dff[dff['STANCE'] == 'Switch'].count()['STANCE']

# %%
x5
# Out:
# 147

# %%
x = np.array(stance)

# %%
y = np.array([x1, x2, x3,x4,x5])

# %%
plt.bar(x,y)
for i in range(len(x)):
    plt.annotate(str(y[i]), xy=(x[i], y[i]))
plt.show()

# %%
pi = result['METHOD'].value_counts().tolist()

# %%
pi
# Out:
# [2393, 2171, 1352, 653, 87, 79, 49, 20, 20, 3]

# %%
lab = result['METHOD'].unique().tolist()

# %%
lab
# Out:
# ['Decision - Unanimous ',
#  'KO/TKO ',
#  'Decision - Split ',
#  'Submission ',
#  'Decision - Majority ',
#  "TKO - Doctor's Stoppage ",
#  'Could Not Continue ',
#  'DQ ',
#  'Other ',
#  'Overturned ']

# %%
plt.figure(figsize=(20,10))
plt.scatter(lab,pi)
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(lab,pi, marker = 'o')
for i in range(len(lab)):
    plt.annotate(str(pi[i]), xy=(lab[i], pi[i]))
plt.title(label = "METHOD OF WIN",
          fontsize = "20"   )
# Out:
# Text(0.5, 1.0, 'METHOD OF WIN')

# %%
wc = result['WEIGHTCLASS'].unique().tolist()
wc
# Out:
# ["Women's Flyweight Bout",
#  'Bantamweight Bout',
#  'Middleweight Bout',
#  'Light Heavyweight Bout',
#  'Featherweight Bout',
#  "Women's Strawweight Bout",
#  'Flyweight Bout',
#  'Welterweight Bout',
#  'Lightweight Bout',
#  'Catch Weight Bout',
#  'Heavyweight Bout',
#  "Women's Featherweight Bout",
#  'UFC Welterweight Title Bout',
#  "Women's Bantamweight Bout",
#  "UFC Women's Bantamweight Title Bout",
#  'UFC Interim Flyweight Title Bout',
#  'UFC Middleweight Title Bout',
#  'UFC Featherweight Title Bout',
#  'UFC Light Heavyweight Title Bout',
#  "UFC Women's Flyweight Title Bout",
#  "UFC Women's Strawweight Title Bout",
#  'UFC Bantamweight Title Bout',
#  'UFC Heavyweight Title Bout',
#  'UFC Flyweight Title Bout',
#  'UFC Lightweight Title Bout',
#  'UFC Interim Bantamweight Title Bout',
#  'UFC Interim Heavyweight Title Bout',
#  "UFC Women's Featherweight Title Bout",
#  'UFC Interim Lightweight Title Bout',
#  'UFC Interim Middleweight Title Bout',
# ...

# %%
rnd = result['ROUND'].value_counts()
rnd
# Out:
# 3    3428
# 1    1991
# 2    1123
# 5     245
# 4      40
# Name: ROUND, dtype: int64

# %%
labels = ('round 3','round 1', 'round 2', 'round 5', 'round 4')
explode = (0 , 0 , 0, 0 ,0.1)

plt.pie(rnd, explode=explode, labels=labels,autopct='%1.1f%%',
    startangle=90)

plt.title('FIGHTS FINISHED IN DIFF ROUNDS')
plt.show()
